# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore') 
import statistics as stats

# %%
shar_tack = pd.read_csv("/Users/lcorrea/Desktop/sharckattack/attacks.csv",sep=',', encoding='latin-1')

# %%
shar_tack.head()
# Out:
#   Case Number         Date    Year        Type    Country             Area  \
# 0  2018.06.25  25-Jun-2018  2018.0     Boating        USA       California
# 1  2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA          Georgia
# 2  2018.06.09  09-Jun-2018  2018.0     Invalid        USA           Hawaii
# 3  2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4  2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO           Colima
#
#                          Location     Activity             Name Sex   ...  \
# 0     Oceanside, San Diego County     Paddling      Julie Wolfe    F  ...
# 1  St. Simon Island, Glynn County     Standing  Adyson McNeely     F  ...
# 2                    Habush, Oahu      Surfing      John Denges    M  ...
# 3              Arrawarra Headland      Surfing             male    M  ...
# 4                        La Ticla  Free diving   Gustavo Ramos     M  ...
#
# ...

# %%
shar_tack.shape
# Out:
# (2808, 24)

# %%
#shar_tack.describe().T

# %%
print(shar_tack.columns)
# Out:
# Index(['Case Number', 'Date', 'Year', 'Type', 'Country', 'Area', 'Location',
#        'Activity', 'Name', 'Sex ', 'Age', 'Injury', 'Fatal (Y/N)', 'Time',
#        'Species ', 'Investigator or Source', 'pdf', 'href formula', 'href',
#        'Case Number.1', 'Case Number.2', 'original order', 'Unnamed: 22',
#        'Unnamed: 23'],
#       dtype='object')

# %%
shar_tack.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25723 entries, 0 to 25722
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Case Number             8702 non-null   object
#  1   Date                    6302 non-null   object
#  2   Year                    6300 non-null   float64
#  3   Type                    6298 non-null   object
#  4   Country                 6252 non-null   object
#  5   Area                    5847 non-null   object
#  6   Location                5762 non-null   object
#  7   Activity                5758 non-null   object
#  8   Name                    6092 non-null   object
#  9   Sex                     5737 non-null   object
#  10  Age                     3471 non-null   object
#  11  Injury                  6274 non-null   object
#  12  Fatal (Y/N)             5763 non-null   object
#  13  Time                    2948 non-null   object
# ...

# %%
from datetime import datetime


shar_tack.rename(columns = {'Sex ':'Sex', 'Species ':'Species'}, inplace = True)
# Date convertions
shar_tack['Date'] = pd.to_datetime(shar_tack['Date'], errors='coerce')
shar_tack['Case Number'] = pd.to_datetime(shar_tack['Case Number'], errors='coerce')
shar_tack['Year'] = pd.to_numeric(shar_tack['Year'], errors='coerce', downcast="integer")
shar_tack['Age'] = pd.to_numeric(shar_tack['Age'], errors='coerce')
shar_tack['Case Number.1'] = pd.to_datetime(shar_tack['Case Number'], errors='coerce')
shar_tack['Case Number.2'] = pd.to_datetime(shar_tack['Case Number'], errors='coerce')


shar_tack.astype({
    'Type':'string',
    'Country':'string',
    'Area':'string',
    'Location':'string',
    'Activity':'string',
    'Name':'string',
    'Sex':'string',
    'Species':'string',
    'Injury':'string',
    'Fatal (Y/N)':'string',
    'Investigator or Source':'string',
    'pdf':'string',
    'href formula':'string',
    'href':'string',
    'Time':'string'
}).dtypes
# Out:
# Case Number               datetime64[ns]
# Date                      datetime64[ns]
# Year                               int16
# Type                              string
# Country                           string
# Area                              string
# Location                          string
# Activity                          string
# Name                              string
# Sex                               string
# Age                              float64
# Injury                            string
# Fatal (Y/N)                       string
# Time                              string
# Species                           string
# Investigator or Source            string
# pdf                               string
# href formula                      string
# href                              string
# Case Number.1             datetime64[ns]
# Case Number.2             datetime64[ns]
# original order                   float64
# Unnamed: 22                       object
# ...

# %%
shar_tack.drop_duplicates(inplace=True)

# %%
shar_tack.shape
# Out:
# (2808, 24)

# %%
nan_cols = shar_tack.isna().sum()

# %%
nan_cols
# Out:
# Case Number                 0
# Date                       15
# Year                        0
# Type                        0
# Country                     0
# Area                        0
# Location                    0
# Activity                    0
# Name                        0
# Sex                         0
# Age                       585
# Injury                      0
# Fatal (Y/N)                 0
# Time                        0
# Species                     0
# Investigator or Source      0
# pdf                         0
# href formula                0
# href                        0
# Case Number.1               0
# Case Number.2               0
# original order              0
# Unnamed: 22                 0
# Unnamed: 23                 0
# dtype: int64

# %%
# Keep rows that contain at least 2 non-missing values
shar_tack.dropna(axis=0, thresh=20, inplace = True)

# %%
shar_tack.replace({pd.NaT: 'None'}, inplace=True)
shar_tack.fillna('None', inplace = True)

# %%
shar_tack
# Out:
#      Case Number                 Date  Year        Type     Country  \
# 0     2018-06-25  2018-06-25 00:00:00  2018     Boating         USA
# 1     2018-06-18  2018-06-18 00:00:00  2018  Unprovoked         USA
# 2     2018-06-09  2018-06-09 00:00:00  2018     Invalid         USA
# 3     2018-06-08  2018-06-08 00:00:00  2018  Unprovoked   AUSTRALIA
# 4     2018-06-04  2018-06-04 00:00:00  2018    Provoked      MEXICO
# ...          ...                  ...   ...         ...         ...
# 6239  2068-01-01                 None     0  Unprovoked  MOZAMBIQUE
# 6241  2065-01-01                 None     0  Unprovoked        IRAQ
# 6242  2064-01-01                 None     0  Unprovoked        IRAQ
# 6243  2063-01-01                 None     0  Unprovoked        IRAQ
# 6265  2038-01-01                 None     0  Unprovoked        IRAQ
#
#                  Area                                     Location  \
# 0          California                  Oceanside, San Diego County
# ...

# %%
shar_tack.to_csv('shar_tack.csv', index = True)
